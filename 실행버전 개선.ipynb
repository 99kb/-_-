# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import glob
import os
import re

main_dir = 'G:/python/daegu/전처리' #경로지정
main_dir1 = 'G:/python/daegu' #경로지정

# [f_name for f_name in f_list if re.search('\.csv$' is not None)]

f_list = glob.glob(os.path.join(main_dir,'2*'))# w전처리파일

# %%
years=[]

move_all=  pd.DataFrame()
move_age=  pd.DataFrame()
move_reason=  pd.DataFrame()
move_city=  pd.DataFrame()    
move_sido=  pd.DataFrame() 
in_all=  pd.DataFrame()
in_age=  pd.DataFrame()
in_reason=  pd.DataFrame()
in_city=  pd.DataFrame()    
in_sido=  pd.DataFrame() 
out_all=  pd.DataFrame()    
out_age=  pd.DataFrame()    
out_reason=  pd.DataFrame()    
out_city=  pd.DataFrame()    
out_sido=  pd.DataFrame() 
all_sido_move_1= pd.DataFrame()    
all_sido_move_2= pd.DataFrame()    
all_age_move= pd.DataFrame()    
all_reason_move= pd.DataFrame()    
all_sido_in= pd.DataFrame()    
all_age_in= pd.DataFrame()    
all_reason_in= pd.DataFrame()    
all_sido_out= pd.DataFrame()    
all_reason_out= pd.DataFrame()    
all_age_out= pd.DataFrame()    

for m,k in enumerate(f_list):  
    i= k[20:24]
    globals()['pop_juso_{}'.format(i)] = pd.read_csv(f_list[m],encoding= 'cp949')
    globals()['pop_juso_{}'.format(i)].drop(columns ='Unnamed: 0',inplace =True)
    years.append(int(i))

# %%
pop_juso_2011
# Out:
#            전입년  전입월  전입자_관계 전입자_만나이  전입자_성별     전입시도 전입시군구  전입동읍면   전출시도  \
# 0         2011    1     1.0  50~54세     2.0    서울특별시   종로구  청운효자동  서울특별시
# 1         2011    1     1.0  30~34세     2.0    서울특별시   종로구  청운효자동  서울특별시
# 2         2011    1     1.0  45~49세     1.0    서울특별시   종로구  청운효자동  서울특별시
# 3         2011    1     9.0  30~34세     1.0    서울특별시   종로구  청운효자동  서울특별시
# 4         2011    1     7.0  40~44세     2.0    서울특별시   종로구  청운효자동  서울특별시
# ...        ...  ...     ...     ...     ...      ...   ...    ...    ...
# 11205195  2011   12     8.0    0~4세     4.0     경상남도   진주시    가호동   경상남도
# 11205196  2011    2     3.0   05~9세     3.0     경상남도   통영시    무전동   경상남도
# 11205197  2011    3     8.0  45~49세     1.0     경상남도   양산시    소주동   경상남도
# 11205198  2011   10     6.0  80세 이상     1.0     경상남도   산청군    산청읍   경상남도
# 11205199  2011    2     5.0    0~4세     4.0  제주특별자치도   제주시    한림읍   전라남도
#
#          전출시군구  전출동읍면  사유
# 0          종로구  청운효자동  가족
# 1          종로구  청운효자동  주택
# 2          종로구    사직동  주택
# 3          성북구    석관동  직업
# 4          양천구   신정3동  주택
# ...        ...    ...  ..
# 11205195   진주시    가호동  기타
# 11205196   통영시    용남면  주택
# 11205197   양산시    소주동  가족
# 11205198   산청군    산청읍  주택
# 11205199   강진군    도암면  기타
#
# [11205200 rows x 12 columns]

# %%
def make_df1(year):    
    #전입 전출  같은 도시 제외
    globals()['select_in{}'.format(year)] = globals()['pop_juso_{}'.format(year)][(globals()['pop_juso_{}'.format(year)]["전입시도"] == Select_City)]
    globals()['select_in{}'.format(year)] = globals()['select_in{}'.format(year)][(globals()['select_in{}'.format(year)]["전출시도"] != Select_City)]
    globals()['select_out{}'.format(year)]= globals()['pop_juso_{}'.format(year)][(globals()['pop_juso_{}'.format(year)]["전출시도"] == Select_City)]
    globals()['select_out{}'.format(year)]= globals()['select_out{}'.format(year)][(globals()['select_out{}'.format(year)]["전입시도"] != Select_City)] 
    
    select1 = globals()['pop_juso_{}'.format(year)]["전출시도"]== Select_City
    select2 = globals()['pop_juso_{}'.format(year)]["전입시도"] == Select_City
    globals()['select_inout{}'.format(year)] =globals()['pop_juso_{}'.format(year)][select1 | select2]
    select3 = globals()['select_inout{}'.format(year)]["전입시도"] != globals()['select_inout{}'.format(year)]["전출시도"]
    globals()['select_inout{}'.format(year)] =globals()['select_inout{}'.format(year)][select3]
    globals()['select_inout{}'.format(year)].reset_index() 
    
    file = f'{year}_{Select_City}_타도시 이동데이터.csv'
    juso_code = pd.read_excel(os.path.join(main_dir1, '설명', '2020_국내인구이동통계_파일설계서(코드집포함)(공공용).xlsx'),
                sheet_name= '행정구역코드 등록 및 말소 내역', skiprows=3)
    abcd= juso_code.iloc[:,1].unique()
    if select_year != "전체기간":
        if os.path.isfile(file):
            print(f"{year}년도 {Select_City}_csv는 이전에 생성되었습니다.'")
        else:    
            if (Select_City in abcd):
                print(f"{year}년도 csv 생성중'")
                globals()['select_inout{}'.format(year)].to_csv(f'{year}_{Select_City}_시도간 이동데이터.csv',encoding= 'cp949')  
            else:
                print("잘못된 값")
    else:
        print(f'{year}..')

# %%
def make_df2():
    #초기화
    globals()['move_all']= pd.DataFrame()
    globals()['move_age']= pd.DataFrame()
    globals()['move_reason']= pd.DataFrame()
    globals()['move_city']= pd.DataFrame()
    globals()['move_sido']= pd.DataFrame()
    globals()['in_all']= pd.DataFrame()
    globals()['in_age']= pd.DataFrame()
    globals()['in_reason']= pd.DataFrame()
    globals()['in_city']= pd.DataFrame()
    globals()['in_sido']= pd.DataFrame()
    globals()['out_all']= pd.DataFrame()    
    globals()['out_age']= pd.DataFrame()    
    globals()['out_reason']= pd.DataFrame()    
    globals()['out_city']= pd.DataFrame()    
    globals()['out_sido']= pd.DataFrame()  
    

    for year in years:
        make_df1(year)
        #대구시 전입(대구in)- 대구시전출데이터의 전출(대구out)== 순이동
        abcd =globals()['select_in{}'.format(year)].groupby(["전입시도"]).size()
        efg= globals()['select_out{}'.format(year)].groupby(["전출시도"]).size()
        move_s= abcd - efg
        globals()['move_all']= pd.concat([globals()['move_all'],move_s],axis=1)
        globals()['in_all'] = pd.concat([globals()['in_all'],abcd],axis=1)
        globals()['out_all']= pd.concat([globals()['out_all'],efg],axis=1)    
        # in_city -대구에서 어디로 나갓는지/ out 어디서 대구로 들어왓는지
        in_a = globals()['select_in{}'.format(year)].groupby(["전출시도"]).size()
        out_a = globals()['select_out{}'.format(year)].groupby(["전입시도"]).size()
        aaa= in_a - out_a
        globals()['move_city']= pd.concat([ globals()['move_city'],aaa],axis=1)
        globals()['in_city']= pd.concat([globals()['in_city'],in_a],axis=1)
        globals()['out_city']= pd.concat([globals()['out_city'],out_a],axis=1)    

        in_b=globals()['select_in{}'.format(year)].groupby(["사유"]).size()
        out_b=globals()['select_out{}'.format(year)].groupby(["사유"]).size()
        bbb= in_b-out_b
        globals()['move_reason']= pd.concat([ globals()['move_reason'],bbb],axis=1)    
        globals()['in_reason']= pd.concat([globals()['in_reason'],in_b],axis=1)    
        globals()['out_reason']= pd.concat([globals()['out_reason'],out_b],axis=1)        

        in_c = globals()['select_in{}'.format(year)].groupby(["전입자_만나이"]).size()
        out_c = globals()['select_out{}'.format(year)].groupby(["전입자_만나이"]).size()
        ccc= in_c-out_c
        globals()['move_age']= pd.concat([globals()['move_age'], ccc],axis=1)
        globals()['in_age']= pd.concat([globals()['in_age'], in_c],axis=1)
        globals()['out_age']= pd.concat([globals()['out_age'], out_c],axis=1)

        abcd =globals()['select_in{}'.format(year)].groupby(["전입시군구"]).size()
        efg= globals()['select_out{}'.format(year)].groupby(["전출시군구"]).size()
        move_s= abcd - efg
        globals()['move_sido']= pd.concat([globals()['move_sido'],move_s],axis=1)
        globals()['in_sido'] = pd.concat([globals()['in_sido'],abcd],axis=1)
        globals()['out_sido']= pd.concat([globals()['out_sido'],efg],axis=1)    
        
    
    blank = pd.DataFrame()
    blank[0]=[years]
    blank = pd.DataFrame()
    for i,year in enumerate(years):
        blank[0,i]=[year]
    blank.columns= years
    blank.rename(index={0: '-----'},inplace=True)
        
    blank.columns=[years]
    in_all.columns=[years]
    in_city.columns=[years]
    in_reason.columns=[years]
    in_age.columns=[years]
    
    # csv_make= input("전입/전출/순이동 요약 csv 파일을 다운받으시겠습니까?   [예  - 입력시 CSV 파일 생성 / 원하지 않을 시 아무 키나 입력]")
    # if csv_make == "예":
    in_csv = pd.concat([in_all,blank])
    in_csv = pd.concat([in_csv,in_reason])
    in_csv = pd.concat([in_csv,blank])
    in_csv = pd.concat([in_csv,in_city])
    in_csv = pd.concat([in_csv,blank])
    in_csv = pd.concat([in_csv,in_age])
    in_csv.to_csv(f"{len(years)}개년_{Select_City}_전입 요약.csv",encoding= 'cp949')  

    out_all.columns=[years]
    out_city.columns=[years]
    out_reason.columns=[years]
    out_age.columns=[years]

    out_csv = pd.concat([out_all,blank])
    out_csv = pd.concat([out_csv,out_reason])
    out_csv = pd.concat([out_csv,blank])
    out_csv = pd.concat([out_csv,out_city])
    out_csv = pd.concat([out_csv,blank])
    out_csv = pd.concat([out_csv,out_age])
    out_csv.to_csv(f"{len(years)}개년_{Select_City}_전출 요약.csv",encoding= 'cp949')  

    move_all.columns=[years]
    move_city.columns=[years]
    move_reason.columns=[years]
    move_age.columns=[years]

    move_csv = pd.concat([move_all,blank])
    move_csv = pd.concat([move_csv,move_reason])
    move_csv = pd.concat([move_csv,blank])
    move_csv = pd.concat([move_csv,move_city])
    move_csv = pd.concat([move_csv,blank])
    move_csv = pd.concat([move_csv,move_age])
    move_csv.to_csv(f"{len(years)}개년_{Select_City}_순이동 요약.csv",encoding= 'cp949')

# %%
def go_to_city_year(Select_City,전출도시,year):
    globals()[f'{전출도시}_to_{Select_City}'] = globals()['pop_juso_{}'.format(year)][(globals()['pop_juso_{}'.format(year)]["전입시도"] == Select_City)]
    globals()[f'{전출도시}_to_{Select_City}'] = globals()[f'{전출도시}_to_{Select_City}'][(globals()[f'{전출도시}_to_{Select_City}']["전출시도"] == 전출도시)]

def go_to_city_all(select,전출도시):
    globals()['all_sido_in']= pd.DataFrame()    
    globals()['all_sido_out']= pd.DataFrame()  
    globals()['all_sido_move_1']= pd.DataFrame()  
    globals()['all_sido_move_2'] = pd.DataFrame()  

    globals()['all_reason_move'] = pd.DataFrame()  
    globals()['all_reason_in'] = pd.DataFrame()  
    globals()['all_reason_out'] = pd.DataFrame()  
    globals()['all_age_move'] = pd.DataFrame()  
    globals()['all_age_in'] = pd.DataFrame()  
    globals()['all_age_out'] = pd.DataFrame()  
    globals()['도시비교_순이동'] =pd.DataFrame()  
    globals()['도시비교_유입'] =pd.DataFrame()  
    globals()['도시비교_유출'] =pd.DataFrame()  
    for year in years:
    #변수 만들기    
        go_to_city_year(select,전출도시,year)
        go_to_city_year(전출도시,select,year)
    #전입
        ㅇㅇ=globals()[f'{전출도시}_to_{select}'].groupby(globals()[f'{전출도시}_to_{select}']["전입시군구"]).size() 
        globals()['all_sido_in']= pd.concat([globals()['all_sido_in'], ㅇㅇ],axis=1)
        
        ㅇㅇ=globals()[f'{전출도시}_to_{select}'].groupby(globals()[f'{전출도시}_to_{select}']["사유"]).size() 
        globals()['all_reason_in']= pd.concat([globals()['all_reason_in'], ㅇㅇ],axis=1)
        
        ㅇㅇ=globals()[f'{전출도시}_to_{select}'].groupby(globals()[f'{전출도시}_to_{select}']["전입자_만나이"]).size() 
        globals()['all_age_in']= pd.concat([globals()['all_age_in'], ㅇㅇ],axis=1)
        a = globals()[f'{전출도시}_to_{select}']
        aab22b순이동 = a.groupby(a["전입시도"]).size() 
        globals()['도시비교_유입']= pd.concat([globals()['도시비교_유입'], aab22b순이동],axis=1)
        
    #전출
        b = globals()[f'{select}_to_{전출도시}']
        a232abb순이동 = b.groupby(b["전출시도"]).size() 
        globals()['도시비교_유출']= pd.concat([globals()['도시비교_유출'], a232abb순이동],axis=1)
        
        ㄴㄴ=globals()[f'{select}_to_{전출도시}'].groupby(globals()[f'{select}_to_{전출도시}']["전출시군구"]).size() 
        globals()['all_sido_out']= pd.concat([globals()['all_sido_out'], ㄴㄴ],axis=1)
        
        ㅇㅇ=globals()[f'{select}_to_{전출도시}'].groupby(globals()[f'{select}_to_{전출도시}']["사유"]).size() 
        globals()['all_reason_out']= pd.concat([globals()['all_reason_out'], ㅇㅇ],axis=1)
        
        ㅇㅇ=globals()[f'{select}_to_{전출도시}'].groupby(globals()[f'{select}_to_{전출도시}']["전입자_만나이"]).size() 
        globals()['all_age_out']= pd.concat([globals()['all_age_out'], ㅇㅇ],axis=1)
        
    #순이동
        a = globals()[f'{전출도시}_to_{select}']
        b = globals()[f'{select}_to_{전출도시}']
    

        aabb순이동 = a.groupby(a["전입시도"]).size() - b.groupby(b["전출시도"]).size()
        globals()['도시비교_순이동']= pd.concat([globals()['도시비교_순이동'], aabb순이동],axis=1)

        aa_순이동 = a.groupby(a["전입시군구"]).size() - b.groupby(b["전출시군구"]).size()
        bb_순이동 = b.groupby(b["전입시군구"]).size() - a.groupby(a["전출시군구"]).size()
        globals()['all_sido_move_1']= pd.concat([globals()['all_sido_move_1'], aa_순이동],axis=1)
        globals()['all_sido_move_2']= pd.concat([globals()['all_sido_move_2'], bb_순이동],axis=1)


        aa_이유순이동 = a.groupby(a["사유"]).size() - b.groupby(b["사유"]).size()
        globals()['all_reason_move']= pd.concat([globals()['all_reason_move'], aa_이유순이동],axis=1)

        aa나이_순이동 = a.groupby(a["전입자_만나이"]).size() - b.groupby(b["전입자_만나이"]).size()
        globals()['all_age_move']= pd.concat([globals()['all_age_move'], aa나이_순이동],axis=1)
        # aa나이_순이동.to_csv("대구 서울 나이.csv",encoding= 'cp949')

# %% [markdown]
# # 1.연도별 유입인구 현황 #

# %%
def in_graph(select_year):
    # dsds
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    globals()['select_in{}'.format(select_year)].groupby(globals()['select_in{}'.format(select_year)]["전출시도"]).size().plot.bar(plt.figure(figsize=(10,10))) 
    plt.title(f'{select_year}_{Select_City}_유입 도시',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_유입 도시')
    
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 6}
    globals()['select_in{}'.format(select_year)].groupby(globals()['select_in{}'.format(select_year)]["사유"]).size().plot.pie(figsize=(10,10), autopct= '%0.1f%%',wedgeprops=wedgeprops)
    plt.title(f' {select_year}_{Select_City}_유입_사유',fontsize=20)
    plt.ylabel("")
    plt.savefig(f' {select_year}_{Select_City}_유입_사유')
    
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    globals()['select_in{}'.format(select_year)].groupby(globals()['select_in{}'.format(select_year)]["전입자_만나이"]).size().plot.barh(plt.figure(figsize=(10,10))) 
    plt.title(f'{select_year}_{Select_City}_유입_연령',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_유입_연령')
    plt.show()

def in_graph_reason(select_year,사유선택):

    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    a = globals()['select_in{}'.format(select_year)][globals()['select_in{}'.format(select_year)]["사유"]==사유선택]
    a.groupby(["전출시도"]).size().plot.bar(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_유입_{사유선택}사유_도시',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유입_{사유선택}_도시')
    
    plt.figure(figsize=(10,10))
    a.groupby(["전입자_만나이"]).size().plot.barh(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_유입_{사유선택}_사유_연령',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유입_{사유선택}_연령')
    plt.show()

def in_graph_age(select_year,연령대_선택):
    a = globals()['select_in{}'.format(select_year)][globals()['select_in{}'.format(select_year)]["전입자_만나이"]==연령대_선택]
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 6}
    a.groupby(["사유"]).size().plot.pie(figsize=(10,10), autopct= '%0.1f%%',wedgeprops=wedgeprops)
    plt.ylabel("")
    plt.title(f' {select_year}_{Select_City}_유입_{연령대_선택}_사유',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유입_{연령대_선택}_사유')
    
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    a.groupby(["전출시도"]).size().plot.bar()
    plt.title(f' {select_year}_{Select_City}_유입_{연령대_선택}_도시',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유입_{연령대_선택}_도시')
    plt.show()

def in_graph_city(select_year, 도시선택):
    a = globals()['select_in{}'.format(select_year)][globals()['select_in{}'.format(select_year)]["전출시도"]==도시선택]
    a.groupby(["전입자_만나이"]).size().plot.barh(figsize=(10,10))
    plt.title(f'{select_year}_{Select_City} 유입_{도시선택}_유출_연령',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City} 유입_{도시선택}_유출_연령')
    plt.show()
    
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 6}
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    a.groupby(["사유"]).size().plot.pie(figsize=(10,10), autopct= '%0.1f%%',wedgeprops=wedgeprops)
    plt.ylabel("")
    plt.title(f'{select_year}_{Select_City}_유입_{도시선택}_유출_사유',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_유입_{도시선택}_유출_사유')
    plt.show()
    
    abcd =a.groupby(["전입시군구"]).size()
    abcd.plot.barh(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_유입 {도시선택}_유출_시군구',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유입 {도시선택}_유출_시군구')
    plt.show()

# %% [markdown]
# # 2. 연도별 유출인구 현황 #

# %%
def out_graph(select_year):
    
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    globals()['select_out{}'.format(select_year)].groupby(globals()['select_out{}'.format(select_year)]["전입시도"]).size().plot.bar(plt.figure(figsize=(10,10))) 
    plt.title(f'{select_year}_{Select_City}_유출 도시',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_유출 도시')
    
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 6}
    globals()['select_out{}'.format(select_year)].groupby(globals()['select_out{}'.format(select_year)]["사유"]).size().plot.pie(figsize=(10,10), autopct= '%0.1f%%',wedgeprops=wedgeprops)
    plt.title(f' {select_year}_{Select_City}_유출_사유',fontsize=20)
    plt.ylabel("")
    plt.savefig(f' {select_year}_{Select_City}_유출_사유')
    
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    globals()['select_out{}'.format(select_year)].groupby(globals()['select_out{}'.format(select_year)]["전입자_만나이"]).size().plot.barh(plt.figure(figsize=(10,10))) 
    plt.title(f'{select_year}_{Select_City}_유출_연령',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_유출_연령')
    plt.show()

def out_graph_reason(select_year,사유선택):

    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    a = globals()['select_out{}'.format(select_year)][globals()['select_out{}'.format(select_year)]["사유"]==사유선택]
    a.groupby(["전입시도"]).size().plot.bar(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_유출_{사유선택}사유_도시',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유출_{사유선택}_도시')
    
    plt.figure(figsize=(10,10))
    a.groupby(["전입자_만나이"]).size().plot.barh(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_유출_{사유선택}_사유_연령',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유출_{사유선택}_연령')
    plt.show()

def out_graph_age(select_year,연령대_선택):
    a = globals()['select_out{}'.format(select_year)][globals()['select_out{}'.format(select_year)]["전입자_만나이"]==연령대_선택]
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 6}
    a.groupby(["사유"]).size().plot.pie(figsize=(10,10), autopct= '%0.1f%%',wedgeprops=wedgeprops)
    plt.ylabel("")
    plt.title(f' {select_year}_{Select_City}_유출_{연령대_선택}_사유',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유출_{연령대_선택}_사유')
    
    plt.figure(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    a.groupby(["전입시도"]).size().plot.bar()
    plt.title(f' {select_year}_{Select_City}_유출_{연령대_선택}_도시',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유출_{연령대_선택}_도시')
    plt.show()

def out_graph_city(select_year, 도시선택):
    a = globals()['select_out{}'.format(select_year)][globals()['select_out{}'.format(select_year)]["전입시도"]==도시선택]
    a.groupby(["전입자_만나이"]).size().plot.barh(figsize=(10,10))
    plt.rc('font', family='Malgun Gothic',size= 20) 
    plt.title(f'{select_year}_{Select_City} 유출_{도시선택}_유출_연령',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City} 유출_{도시선택}_유입_연령')
    plt.show()
    
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 6}
    plt.figure(figsize=(10,10))
    a.groupby(["사유"]).size().plot.pie(figsize=(10,10), autopct= '%0.1f%%',wedgeprops=wedgeprops)
    plt.ylabel("")
    plt.title(f'{select_year}_{Select_City}_유출_{도시선택}_유출_사유',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_유출_{도시선택}_유입_사유')
    plt.show()
    
    abcd =a.groupby(["전출시군구"]).size()
    abcd.plot.barh(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_유출 {도시선택}_유입_시군구',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_유출 {도시선택}_유입_시군구')
    plt.show()

# %% [markdown]
# # 3. 연도별 순이동 #

# %%
def move_graph(select_year):
    plt.rcParams['axes.unicode_minus'] = False
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 6}
    
    in_a = globals()['select_in{}'.format(select_year)].groupby(globals()['select_in{}'.format(select_year)]["전출시도"]).size()
    out_a = globals()['select_out{}'.format(select_year)].groupby(globals()['select_out{}'.format(select_year)]["전입시도"]).size()
    aaa= in_a - out_a

    in_b=globals()['select_in{}'.format(select_year)].groupby(globals()['select_in{}'.format(select_year)]["사유"]).size()
    out_b=globals()['select_out{}'.format(select_year)].groupby(globals()['select_out{}'.format(select_year)]["사유"]).size()
    bbb= in_b-out_b

    in_c = globals()['select_in{}'.format(select_year)].groupby(globals()['select_in{}'.format(select_year)]["전입자_만나이"]).size()
    out_c = globals()['select_out{}'.format(select_year)].groupby(globals()['select_out{}'.format(select_year)]["전입자_만나이"]).size()
    ccc= in_c-out_c

    plt.figure(figsize=(10,10))
    aaa.plot.bar()
    plt.title(f'{select_year}_{Select_City}_순이동_도시 ',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_순이동_도시 ')
    plt.show()

    plt.figure(figsize=(10,10))
    bbb.plot.bar()
    plt.title(f'{select_year}_{Select_City}_순이동_사유 ',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_순이동_사유 ')
    plt.show()
    
    plt.figure(figsize=(10,10))
    ccc.plot.bar()
    plt.title(f'{select_year}_{Select_City}_순이동_연령 ',fontsize=20)
    plt.savefig(f'{select_year}_{Select_City}_순이동_연령 ')
    plt.show()
    
def move_graph_age(select_year,연령대_선택):
    in_a = globals()['select_in{}'.format(select_year)][globals()['select_in{}'.format(select_year)]["전입자_만나이"]==연령대_선택]
    out_a = globals()['select_out{}'.format(select_year)][globals()['select_out{}'.format(select_year)]["전입자_만나이"]==연령대_선택]
    
    bbb=in_a.groupby(["사유"]).size()-out_a.groupby(["사유"]).size()
    plt.figure(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_순이동_{연령대_선택}_사유',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_순이동_{연령대_선택}_사유')
    bbb.plot.bar()
    plt.show()
    
    aaa= in_a.groupby(["전출시도"]).size()- out_a.groupby(["전입시도"]).size()
    plt.figure(figsize=(10,10))
    aaa.plot.bar()
    plt.title(f' {select_year}_{Select_City}_순이동_{연령대_선택}_도시',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_순이동_{연령대_선택}_도시')
    plt.show()
    

def move_graph_city(select_year, 도시선택):
    in_a = globals()['select_in{}'.format(select_year)][globals()['select_in{}'.format(select_year)]["전출시도"]==도시선택]
    out_a = globals()['select_out{}'.format(select_year)][globals()['select_out{}'.format(select_year)]["전입시도"]==도시선택]
    
    aaa= in_a.groupby(["전입자_만나이"]).size()- out_a.groupby(["전입자_만나이"]).size()
    plt.figure(figsize=(10,10))
    aaa.plot.bar()
    plt.title(f' {select_year}_{Select_City}_순이동_{도시선택}_연령',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_순이동_{도시선택}_연령')
    plt.show()
    
    bbb=in_a.groupby(["사유"]).size()-out_a.groupby(["사유"]).size()
    plt.figure(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_순이동_{도시선택}_사유',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_순이동_{도시선택}_사유')
    bbb.plot.bar()
    plt.show()

    abcd =in_a.groupby(["전입시군구"]).size()
    efg= out_a.groupby(["전출시군구"]).size()
    move_s= abcd - efg    
    move_s.plot.bar(figsize=(10,10))
    plt.title(f' {select_year}_{Select_City}_순이동_{도시선택}_시군구',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_순이동_{도시선택}_시군구')
    plt.show()
    
def move_graph_reason(select_year,사유선택):
    in_a = globals()['select_in{}'.format(select_year)][globals()['select_in{}'.format(select_year)]["사유"]==사유선택]
    out_a = globals()['select_out{}'.format(select_year)][globals()['select_out{}'.format(select_year)]["사유"]==사유선택]
    
    aaa= in_a.groupby(["전출시도"]).size()- out_a.groupby(["전입시도"]).size()
    plt.figure(figsize=(10,10))
    aaa.plot.bar()
    plt.title(f' {select_year}_{Select_City}_순이동_{사유선택}_도시',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_순이동_{사유선택}_도시')
    plt.show()
    
    bbb=in_a.groupby(["전입자_만나이"]).size()-out_a.groupby(["전입자_만나이"]).size()
    plt.figure(figsize=(10,10))
    bbb.plot.bar()
    plt.title(f' {select_year}_{Select_City}_순이동_{사유선택}_연령',fontsize=20)
    plt.savefig(f' {select_year}_{Select_City}_순이동_{사유선택}_연령')
    plt.show()

# %% [markdown]
# # 전체 그래프

# %%
# 전입 
def all_in_graph():
    in_all.columns=[years]
    in_age.columns=[years]
    in_reason.columns=[years]
    in_city.columns=[years]
    in_sido.columns=[years]
    in_all_ = in_all.T
    in_reason_= in_reason.T
    
    plt.rcParams['figure.figsize'] = [15, 10]
    plt.rc('font',family='Malgun Gothic', size=12)   #기본글자크기
    plt.rcParams['axes.unicode_minus'] = False

    in_all_.plot(marker="o")
    plt.title(f'{len(years)}개년_{Select_City}_유입',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유입')
    plt.show()

    sns.heatmap(in_age, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_유입_연령',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유입_연령')
    plt.show()

    in_reason_.plot(marker="o")
    plt.title(f'{len(years)}개년_{Select_City}_유입_사유',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유입_사유')
    plt.show()

    sns.heatmap(in_city, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_유입_도시',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유입_도시')
    plt.show()

    sns.heatmap(in_sido, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_유입_시군구',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유입_시군구')
    plt.show()

# %%
#전출
def all_out_graph():

    out_all.columns=[years]
    out_age.columns=[years]
    out_reason.columns=[years]
    out_city.columns=[years]
    out_sido.columns=[years]
    out_all_= out_all.T
    out_reason_= out_reason.T

    plt.rcParams['figure.figsize'] =  [15, 10]
    plt.rc('font',family='Malgun Gothic', size=12)   #기본글자크기
    plt.rcParams['axes.unicode_minus'] = False

    out_all_.plot(marker="o")
    plt.title(f'{len(years)}개년_{Select_City}_유출',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유출')
    plt.show()

    sns.heatmap(out_age, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_유출_연령',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유출_연령')
    plt.show()

    out_reason_.plot(marker="o")
    plt.title(f'{len(years)}개년_{Select_City}_유출_사유',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유출_사유')
    plt.show()

    sns.heatmap(out_city, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_유출_도시',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유출_도시')
    plt.show()

    sns.heatmap(out_sido, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_유출_시군구',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_유출_시군구')
    plt.show()

# %%
def all_move_graph():
    move_all.columns=[years]
    move_age.columns=[years]
    move_reason.columns=[years]
    move_city.columns=[years]
    move_sido.columns=[years]
    move_all_= move_all.T
    move_reason_= move_reason.T  

    plt.rc('font', size=10)   #기본글자크기
    plt.rcParams['axes.unicode_minus'] = False
    plt.rcParams['figure.figsize'] =  [15, 10]
    
    move_all_.plot(marker="o")
    plt.title(f'{len(years)}개년_{Select_City}_순이동',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_순이동')
    plt.show()

    sns.heatmap(move_age, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_순이동_연령',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_순이동_연령')
    plt.show()

    move_reason_.plot(marker="o")
    plt.title(f'{len(years)}개년_{Select_City}_순이동_사유',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_순이동_사유')
    plt.show()

    sns.heatmap(move_city, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_순이동_도시',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_순이동_도시')
    plt.show()
    
    sns.heatmap(move_sido, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{Select_City}_순이동_시군구',fontsize=20)
    plt.savefig(f'{len(years)}개년_{Select_City}_순이동_시군구')
    plt.show()

# %%
def g_a_move_b(select,비교도시,year):
    go_to_city_year(select,비교도시,year)
    go_to_city_year(비교도시,select,year)
    
    sido_in=globals()[f'{비교도시}_to_{Select_City}'].groupby(globals()[f'{비교도시}_to_{select}']["전입시군구"]).size() 
    sido_out=globals()[f'{select}_to_{비교도시}'].groupby(globals()[f'{select}_to_{비교도시}']["전입시군구"]).size() 
    sido_move = sido_in -sido_out
    
    plt.rcParams['figure.figsize'] =  [15, 10]
    plt.rc('font',family='Malgun Gothic', size=12)   #기본글자크기
    plt.rcParams['axes.unicode_minus'] = False

    유입 =globals()[f'{비교도시}_to_{Select_City}'].groupby(globals()[f'{비교도시}_to_{select}']["전출시군구"]).size() 
    유입.plot.bar()
    plt.title(f'{year}_{select}유입_{비교도시}_시군구',fontsize=20)
    plt.savefig(f'{year}_{select}유입_{비교도시}_시군구')
    plt.show()

    유출 = globals()[f'{select}_to_{비교도시}'].groupby(globals()[f'{select}_to_{비교도시}']["전입시군구"]).size()
    유출.plot.bar()
    plt.title(f'{year}_{select}유출_{비교도시}_시군구',fontsize=20)
    plt.savefig(f'{year}_{select}유출_{비교도시}_시군구')
    plt.show()

    c_순이동 =globals()[f'{비교도시}_to_{Select_City}'].groupby(globals()[f'{비교도시}_to_{Select_City}']["전출시군구"]).size() - globals()[f'{select}_to_{비교도시}'].groupby(globals()[f'{select}_to_{비교도시}']["전입시군구"]).size()
    c_순이동.plot.bar()
    plt.title(f'{year}_{select}순이동_{비교도시}_시군구',fontsize=20)
    plt.savefig(f'{year}_{select}순이동_{비교도시}_시군구')
    plt.show()

# %%
# # 실행
도시명 ={"서울특별시", "대구광역시", "부산광역시", "인천광역시", "광주광역시", "대전광역시", "울산광역시",
                    "경기도", "강원도", "충청북도", "충청남도", "전라북도", "전라남도", "경상북도", "경상남도", "제주특별자치도"}

"경기도" not in 도시명
# 11 not in 도시명
# Out:
# False

# %%
def g_a_out_b_all(select,b):
    도시비교_유출.columns=[years]
    도시비교_유출_=도시비교_유출.T
    all_age_out.columns=[years]
    all_reason_out.columns=[years]
    all_reason_out_= all_reason_out.T
    all_sido_out.columns=[years]
    all_sido_out_=all_sido_out.T

    plt.rcParams['figure.figsize'] = [15, 10]
    plt.rc('font',family='Malgun Gothic', size=12)   #기본글자크기
    plt.rcParams['axes.unicode_minus'] = False

    도시비교_유출_.plot()
    plt.title(f'{len(years)}개년_{b}유입_{select}유출',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유입_{select}유출')
    plt.show()

    sns.heatmap(all_sido_out, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{b}유입_{select}유출_시군구',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유입_{select}유출_시군구')
    plt.show()

    all_reason_out_.plot()
    plt.title(f'{len(years)}개년_{b}유입_{select}유출_사유',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유입_{select}유출_사유')
    plt.show()

    sns.heatmap(all_age_out, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{b}유입_{select}유출_연령',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유입_{select}유출_연령')
    plt.show()
    
    blank = pd.DataFrame()
    for i,year in enumerate(years):
        blank[0,i]=[year]
    blank.columns= [years]
    blank.rename(index={0: '-----'},inplace=True)
    
    out_sido_csv = pd.concat([도시비교_유출,blank])
    out_sido_csv = pd.concat([out_sido_csv,all_sido_out])
    out_sido_csv = pd.concat([out_sido_csv,blank])
    out_sido_csv = pd.concat([out_sido_csv,all_sido_out * -1])
    out_sido_csv = pd.concat([out_sido_csv,blank])
    out_sido_csv = pd.concat([out_sido_csv,  all_reason_out])
    out_sido_csv = pd.concat([out_sido_csv,blank])
    out_sido_csv = pd.concat([out_sido_csv,  all_age_out])
    out_sido_csv.to_csv(f"{len(years)}개년_{Select_City}_{b}_유출 요약.csv",encoding= 'cp949')  
    
def g_a_in_b_all(select,b):
    도시비교_유입.columns=[years]
    도시비교_유입_=도시비교_유입.T
    all_age_in.columns=[years]

    all_reason_in.columns=[years]
    all_reason_in_= all_reason_in.T
    plt.rcParams['figure.figsize'] = [15, 10]
    plt.rc('font',family='Malgun Gothic', size=12)   #기본글자크기
    plt.rcParams['axes.unicode_minus'] = False
    all_sido_in.columns=[years]
    all_sido_in_=all_sido_in.T

    도시비교_유입_.plot(marker="o")
    plt.title(f'{len(years)}개년_{b}유출_{select} 유입',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유출_{select} 유입')
    plt.show()

    sns.heatmap(all_sido_in, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{b}유출_{select}유입_시군구',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유출_{select}유입_시군구')
    plt.show()

    all_reason_in_.plot()
    plt.title(f'{len(years)}개년_{b}유출_{select} 유입_ 사유',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유출_{select} 유입_ 사유')
    plt.show()

    sns.heatmap(all_age_in, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{b}유출_{select} 유입_연령',fontsize=20)
    plt.savefig(f'{len(years)}개년_{b}유출_{select} 유입_연령')
    plt.show()


    blank = pd.DataFrame()
    for i,year in enumerate(years):
        blank[0,i]=[year]
    blank.columns= [years]
    blank.rename(index={0: '-----'},inplace=True)
    in_sido_csv = pd.concat([도시비교_유입,blank])
    in_sido_csv = pd.concat([in_sido_csv,all_sido_in])
    in_sido_csv = pd.concat([in_sido_csv,blank])
    in_sido_csv = pd.concat([in_sido_csv,all_sido_in * -1])
    in_sido_csv = pd.concat([in_sido_csv,blank])
    in_sido_csv = pd.concat([in_sido_csv,  all_reason_in])
    in_sido_csv = pd.concat([in_sido_csv,blank])
    in_sido_csv = pd.concat([in_sido_csv,  all_age_in])
    in_sido_csv.to_csv(f"{len(years)}개년_{Select_City}_{b}_유입 요약.csv",encoding= 'cp949')

# %%
def g_a_move_b_all(select,비교도시):
    
    all_sido_move_1.columns=[years]
    all_sido_move_2.columns=[years]
    all_reason_move.columns=[years]
    all_age_move.columns=[years]
    
    도시비교_순이동.columns=[years]
    all_sido_move_1_= all_sido_move_1.T
    all_sido_move_2_= all_sido_move_2.T 
    all_reason_move_= all_reason_move.T
    all_age_move_= all_age_move.T
    도시비교_순이동_=도시비교_순이동.T

    plt.rcParams['figure.figsize'] =  [15, 10]
    plt.rc('font',family='Malgun Gothic', size=12)   #기본글자크기
    plt.rcParams['axes.unicode_minus'] = False

    도시비교_순이동_.plot(marker="o")
    plt.title(f'{len(years)}개년_{select}_{비교도시}_순이동',fontsize=20)
    plt.savefig(f'{len(years)}개년_{select}_{비교도시}_순이동')
    plt.show()

    sns.heatmap(all_sido_move_1, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{select}_{비교도시}_순이동_{select}시군구',fontsize=20)
    plt.savefig(f'{len(years)}개년_{select}_{비교도시}_순이동_{select}시군구')
    plt.show()
    if select != 비교도시:
        plt.rcParams['figure.figsize'] = [15, 20]
        sns.heatmap(all_sido_move_2 * -1, linewidths =0, annot=True,fmt=".0f",)
        plt.title(f'{len(years)}개년_{select}_{비교도시}_순이동_{비교도시}시군구',fontsize=20)
        plt.savefig(f'{len(years)}개년_{select}_{비교도시}_순이동_{비교도시}시군구')
        plt.show()
    
    plt.rcParams['figure.figsize'] =  [15, 10]
    all_reason_move_.plot()
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.title(f'{len(years)}개년_{select}_{비교도시} _순이동_사유',fontsize=20)
    plt.savefig(f'{len(years)}개년_{select}_{비교도시} _순이동_사유')
    plt.show()

    sns.heatmap(all_age_move, linewidths =0, annot=True,fmt=".0f",)
    plt.title(f'{len(years)}개년_{select}_ {비교도시}_순이동_연령',fontsize=20)
    plt.savefig(f'{len(years)}개년_{select}_ {비교도시}_순이동_연령')
    plt.show()
    
    blank = pd.DataFrame()
    for i,year in enumerate(years):
        blank[0,i]=[year]
    blank.columns= [years]
    blank.rename(index={0: '-----'},inplace=True)
    
    move_sido_csv = pd.concat([도시비교_순이동,blank])
    move_sido_csv = pd.concat([move_sido_csv,all_sido_move_1])
    move_sido_csv = pd.concat([move_sido_csv,blank])
    move_sido_csv = pd.concat([move_sido_csv,all_sido_move_2 * -1])
    move_sido_csv = pd.concat([move_sido_csv,blank])
    move_sido_csv = pd.concat([move_sido_csv,  all_reason_move])
    move_sido_csv = pd.concat([move_sido_csv,blank])
    move_sido_csv = pd.concat([move_sido_csv,  all_age_move])
    move_sido_csv.to_csv(f"{len(years)}개년_{Select_City}_{비교도시}_순이동 요약.csv",encoding= 'cp949')

# %% [markdown]
# # 실행

# %%
# # 실행
도시명 ={"서울특별시", "대구광역시", "부산광역시", "인천광역시", "광주광역시", "대전광역시", "울산광역시",
                        "경기도", "강원도", "충청북도", "충청남도", "전라북도", "전라남도", "경상북도", "경상남도", "제주특별자치도"}

print("")
print("################################################################ \n")    
print("프로그램 시작\n")
print("################################################################ \n")        
print("도시를 선택하세요.\n")
print("(도시예시 : 서울특별시, 대구광역시, 부산광역시, 인천광역시, 광주광역시, 대전광역시, 울산광역시, \n\
                경기도, 강원도, 충청북도, 충청남도, 전라북도, 전라남도, 경상북도, 경상남도, 제주특별자치도)\n")
Select_City= input("도시 선택 : ")
print("****************************************************************")
if Select_City not in 도시명:
    print("잘못된 도시명을 입력하셨습니다.")
    
print('연도를 입력하세요.\n')
print(f' 선택가능 년도 : 전체기간 또는 {years}')
select_year= input("연도선택 : ")
if select_year != "전체기간" :
    if(int(select_year) not in years) :
        print("잘못된 년도를 입력하셨습니다.")
        
        print("****************************************************************")
if(select_year == "전체기간"):
    make_df2()  
    a="예"
    while 1:    
        if a != "예":
            break
        plt.rcParams['axes.unicode_minus'] = False
        plt.rcParams['figure.figsize'] =  [15, 10]
        plt.rc('font',family='Malgun Gothic', size=12)
        all_in_graph()
        all_out_graph()
        all_move_graph()
        print("그래프 저장완료")
        
        while 1: 
            print("")
            print("****************************************************************")
            a= input("도시간 비교를 하시겠습니까?   [예  - 입력시 도시간 비교 / 원하지 않을 시 아무 키나 입력] ")
            if a == "예":
                print("")
                print("도시를 선택하세요.\n")
                print("(도시예시 : 서울특별시, 대구광역시, 부산광역시, 인천광역시, 광주광역시, 대전광역시, 울산광역시, \n\
                경기도, 강원도, 충청북도, 충청남도, 전라북도, 전라남도, 경상북도, 경상남도, 제주특별자치도)\n")
                bb_ci= input("비교 도시 선택 : ")
                if bb_ci not in 도시명:
                    print("잘못된 도시명을 입력하셨습니다. ")
                    
                go_to_city_all(Select_City,bb_ci)
                g_a_in_b_all(Select_City,bb_ci)
                g_a_out_b_all(Select_City,bb_ci)
                g_a_move_b_all(Select_City,bb_ci)
                print("그래프 저장완료")
            else:
                break
elif  (1980<=int(select_year)<=2030):
    make_df1(select_year)  
    plt.rcParams['axes.unicode_minus'] = False
    plt.rc('font', family='Malgun Gothic',size=20 ) 
    plt.rcParams['figure.figsize'] =  [10, 10]
    in_graph(select_year)
    out_graph(select_year)
    move_graph(select_year)
    print("그래프 저장완료")
    
    while 1: 
        print("")
        print("****************************************************************")
        a= input("세부 비교를 하시겠습니까?   [예  - 입력시 세부 비교 / 원하지 않을 시 아무 키나 입력] ")
        if a != "예":
            break  
        print("")
        select_세부= input(f"세부 항목입력 : 도시/사유/연령 ")
        print("")
        print("****************************************************************")
        
        if (select_세부 == "도시"):
            print("")
            print("도시를 선택하세요")
            print("(도시예시 : 서울특별시, 대구광역시, 부산광역시, 인천광역시, 광주광역시, 대전광역시, 울산광역시, \n\
                경기도, 강원도, 충청북도, 충청남도, 전라북도, 전라남도, 경상북도, 경상남도, 제주특별자치도)\n")
            a= input(f"세부 도시 입력:  ")
            
            if a not in 도시명:
                print("잘못된 도시명을 입력하셨습니다.")
            if (Select_City == a ) :#내부이동 구현아직 x
                go_to_city_year(Select_City,a,select_year)
                in_graph_city(select_year,a)    
                move_graph_city(select_year,a)    
                g_a_move_b(Select_City,a,select_year)
                print("그래프 저장완료")
                
            else:
                go_to_city_year(Select_City,a,select_year)
                go_to_city_year(a,Select_City,select_year)
                in_graph_city(select_year,a)    
                out_graph_city(select_year,a)    
                move_graph_city(select_year,a)    
                g_a_move_b(Select_City,a,select_year)  
                print("그래프 저장완료")
                    
        elif (select_세부 == "사유"):
            print("")
            print("사유를 선택하세요")
            print("(사유 목록 : '직업','가족','주택','교육','주거환경','자연환경','기타")
            b= input("사유 입력: ")
            if b not in 사유:
                print("잘못된 사유명을 입력하셨습니다.")
            in_graph_reason(select_year,b)
            out_graph_reason(select_year,b)
            move_graph_reason(select_year,b)     
            print("그래프 저장완료")
            
        elif (select_세부 == "연령"):
            print("")
            print("연령대를 선택하세요")
            print("(연령대 목록 : '0~4세','5~9세','10~14세','15~19세','20~24세','25~29세','30~34세','35~39세','40~44세','45~49세',\n\
                    '50~54세','55~59세','60~64세','65~69세','70~74세','75~79세','80세 이상'\n\ ")
            c= input(f"세부 연령대 입력: ")
            if c not in 연령:
                print("잘못된 연령대를 입력하셨습니다.")
            in_graph_age(select_year,c)    
            out_graph_age(select_year,c)    
            move_graph_age(select_year,c) 
            print("그래프 저장완료")
else:
    print("잘못된 기간을 입력하셨습니다.")
# Out:
# ################################################################
#
# 프로그램 시작
#
# ################################################################
#
# 도시를 선택하세요.
#
# (도시예시 : 서울특별시, 대구광역시, 부산광역시, 인천광역시, 광주광역시, 대전광역시, 울산광역시,
#                 경기도, 강원도, 충청북도, 충청남도, 전라북도, 전라남도, 경상북도, 경상남도, 제주특별자치도)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3736/552623594.py in <module>
#      10 print("(도시예시 : 서울특별시, 대구광역시, 부산광역시, 인천광역시, 광주광역시, 대전광역시, 울산광역시, \n\
#      11                 경기도, 강원도, 충청북도, 충청남도, 전라북도, 전라남도, 경상북도, 경상남도, 제주특별자치도)\n")
# ---> 12 Select_City= input("도시 선택 : ")
#      13 print("****************************************************************")
#      14 if Select_City not in 도시명:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
move_sido.to_csv("9p.csv",encoding= 'cp949') # 8p

# %%
# Select_City= input("도시선택 : 서울특별시,대구광역시,부산광역시,인천광역시,광주광역시,대전광역시,울산광역시,경기도,강원도,충청북도,충청남도,전라북도,전라남도,경상북도,경상남도,제주특별자치도 ")
# select_year= input("검색을 원하는 년도 숫자 또는 '전체기간' 입력   ex)2018    ex) 전체기간 ")
# if(select_year == "전체기간"):
#     make_df2()  
#     a="예"
#     while 1:    
#         if a != "예":
#             break
#         plt.rcParams['axes.unicode_minus'] = False
#         plt.rcParams['figure.figsize'] =  [15, 10]
#         plt.rc('font',family='Malgun Gothic', size=12)
#         all_in_graph()
#         all_out_graph()
#         all_move_graph()
#         while 1: 
#             a= input("도시간 비교를 하시겠습니까?   [예  - 입력시 도시간 비교 / 원하지 않을 시 아무 키나 입력] ")
#             if a == "예":
#                 bb_ci= input(f"비교 도시 입력: 서울특별시,대구광역시,부산광역시,인천광역시,광주광역시,대전광역시,울산광역시,경기도,강원도,충청북도,충청남도,전라북도,전라남도,경상북도,경상남도,제주특별자치도 ")   
#                 go_to_city_all(Select_City,bb_ci)
#                 g_a_in_b_all(Select_City,bb_ci)
#                 g_a_out_b_all(Select_City,bb_ci)
#                 g_a_move_b_all(Select_City,bb_ci)
#             else:
#                 break
# elif (1900<=int(select_year)<=2100):
#     make_df1(select_year)  
#     plt.rcParams['axes.unicode_minus'] = False
#     plt.rc('font', family='Malgun Gothic',size=20 ) 
#     plt.rcParams['figure.figsize'] =  [10, 10]
#     in_graph(select_year)
#     out_graph(select_year)
#     move_graph(select_year)
#     while 1: 
#         a= input("세부 비교를 하시겠습니까?   [예  - 입력시 세부 비교 / 원하지 않을 시 아무 키나 입력] ")
#         if a != "예":
#             break  
#         select_세부= input(f"세부 항목입력 : 도시/사유/연령 ")
#         if (select_세부 == "도시"):
#             a= input(f"세부 도시 입력: 서울특별시,대구광역시,부산광역시,인천광역시,광주광역시,대전광역시,울산광역시,경기도,강원도,충청북도,충청남도,전라북도,전라남도,경상북도,경상남도,제주특별자치도 ")
#             if select_세부 == "":
#                 break      
#             if (Select_City == a ) :#내부이동 구현아직 x
#                 go_to_city_year(Select_City,a,select_year)
#                 in_graph_city(select_year,a)    
#                 move_graph_city(select_year,a)    
#                 g_a_move_b(Select_City,a,select_year)
#             else:
#                 go_to_city_year(Select_City,a,select_year)
#                 go_to_city_year(a,Select_City,select_year)
#                 in_graph_city(select_year,a)    
#                 out_graph_city(select_year,a)    
#                 move_graph_city(select_year,a)    
#                 g_a_move_b(Select_City,a,select_year)       
#         elif (select_세부 == "사유"):
#             b= input("세부 도시 입력: '직업','가족','주택','교육','주거환경','자연환경','기타")
#             in_graph_reason(select_year,b)
#             out_graph_reason(select_year,b)
#             move_graph_reason(select_year,b)     
#         elif (select_세부 == "연령"):
#             c= input(f"세부 연령대 입력: '0~4세','5~9세','10~14세','15~19세','20~24세','25~29세','30~34세','35~39세','40~44세','45~49세','50~54세','55~59세','60~64세','65~69세','70~74세','75~79세','80세 이상' ")
#             in_graph_age(select_year,c)    
#             out_graph_age(select_year,c)    
#             move_graph_age(select_year,c)    
# else:
#     print("잘못된 값입력")

# %%
Select_City="대구광역시"
make_df2()
all_move_graph()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7136/1220150883.py in <module>
#       1 Select_City="대구광역시"
# ----> 2 make_df2()
#       3 all_move_graph()
#
# ~\AppData\Local\Temp/ipykernel_7136/4095891751.py in make_df2()
#      19
#      20     for year in years:
# ---> 21         make_df1(year)
#      22         #대구시 전입(대구in)- 대구시전출데이터의 전출(대구out)== 순이동
#      23         abcd =globals()['select_in{}'.format(year)].groupby(["전입시도"]).size()
#
# ~\AppData\Local\Temp/ipykernel_7136/3108358850.py in make_df1(year)
#      17                 sheet_name= '행정구역코드 등록 및 말소 내역', skiprows=3)
#      18     abcd= juso_code.iloc[:,1].unique()
# ---> 19     if select_year != "전체기간":
#      20         if os.path.isfile(file):
#      21             print(f"{year}년도 {Select_City}_csv는 이전에 생성되었습니다.'")
#
# NameError: name 'select_year' is not defined

# %%
Select_City="대구광역시"
year= 2019
make_df1(year)
지역in = globals()['select_in{}'.format(year)]["전출시도"]=="경상북도"
사유in= globals()['select_in{}'.format(year)]["사유"]=="주택"
globals()['주택{}in'.format(year)] =globals()['select_in{}'.format(year)][지역in & 사유in]
지역out = globals()['select_out{}'.format(year)]["전입시도"]=="경상북도"
사유out= globals()['select_out{}'.format(year)]["사유"]=="주택"
주택2020out =globals()['select_out{}'.format(year)][지역out & 사유out]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7136/1573019449.py in <module>
#       1 Select_City="대구광역시"
#       2 year= 2019
# ----> 3 make_df1(year)
#       4 지역in = globals()['select_in{}'.format(year)]["전출시도"]=="경상북도"
#       5 사유in= globals()['select_in{}'.format(year)]["사유"]=="주택"
#
# ~\AppData\Local\Temp/ipykernel_7136/3108358850.py in make_df1(year)
#      17                 sheet_name= '행정구역코드 등록 및 말소 내역', skiprows=3)
#      18     abcd= juso_code.iloc[:,1].unique()
# ---> 19     if select_year != "전체기간":
#      20         if os.path.isfile(file):
#      21             print(f"{year}년도 {Select_City}_csv는 이전에 생성되었습니다.'")
#
# NameError: name 'select_year' is not defined

# %%
주택2019in
# Out:
#           전입년  전입월  전입자_관계 전입자_만나이  전입자_성별   전입시도 전입시군구 전입동읍면  전출시도 전출시군구  \
# 1526363  2019    1     1.0  25~29세     1.0  대구광역시    중구   동인동  경상북도   영천시
# 1526400  2019    1     1.0  20~24세     2.0  대구광역시    중구   동인동  경상북도   경산시
# 1526435  2019    1     1.0  25~29세     1.0  대구광역시    중구   동인동  경상북도   경산시
# 1526547  2019    2     1.0  25~29세     2.0  대구광역시    중구   동인동  경상북도   고령군
# 1526628  2019    3     1.0  35~39세     1.0  대구광역시    중구   동인동  경상북도   칠곡군
# ...       ...  ...     ...     ...     ...    ...   ...   ...   ...   ...
# 9408947  2019    3     5.0   05~9세     3.0  대구광역시   수성구  고산2동  경상북도   경산시
# 9408956  2019    4     3.0   05~9세     4.0  대구광역시   수성구  고산3동  경상북도   경산시
# 9424620  2019    7     3.0  10~14세     4.0  대구광역시    동구  신암4동  경상북도   영천시
# 9424635  2019    9     8.0  10~14세     3.0  대구광역시    동구  안심1동  경상북도   경산시
# 9424718  2019    8     4.0  65~69세     2.0  대구광역시   수성구  고산1동  경상북도   경산시
#
#         전출동읍면  사유
# 1526363   동부동  주택
# 1526400   북부동  주택
# 1526435   용성면  주택
# 1526547   다산면  주택
# 1526628   석적읍  주택
# ...       ...  ..
# 9408947  서부1동  주택
# 9408956   압량면  주택
# 9424620   금호읍  주택
# 9424635  서부1동  주택
# 9424718   중방동  주택
#
# [7277 rows x 12 columns]

# %%
# a=주택2020in.groupby(["전출시군구"]).size()
# b=주택2020out.groupby(["전입시군구"]).size()
# c= (a-b)*-1
# print(c)
# Out:
# 전출시군구
# 경산시       2570
# 경주시         98
# 고령군        -31
# 구미시         36
# 군위군         11
# 김천시         29
# 문경시        -17
# 봉화군         -4
# 상주시          1
# 성주군         95
# 안동시          9
# 영덕군         -3
# 영양군          2
# 영주시        -18
# 영천시         49
# 예천군         15
# 울릉군        -26
# 울진군        -24
# 의성군         45
# 청도군         91
# 청송군        -19
# 칠곡군        155
# 포항시 남구     -15
# 포항시 북구      98
# dtype: int64

# %%
# select = "대구광역시"
# select2 = "경상북도"
# globals()['select_in_내부포함{}'.format(year)] = globals()['pop_juso_{}'.format(year)][(globals()['pop_juso_{}'.format(year)]["전입시도"] == select)]
# globals()['select_out_내부포함{}'.format(year)]= globals()['pop_juso_{}'.format(year)][(globals()['pop_juso_{}'.format(year)]["전출시도"] == select)]
# globals()['select_in_내부포함_비교{}'.format(year)] = globals()['select_in_내부포함{}'.format(year)][(globals()['select_in_내부포함{}'.format(year)]["전출시도"] == select2)]
# globals()['select_out_내부포함_비교{}'.format(year)]= globals()['select_out_내부포함{}'.format(year)][(globals()['select_out_내부포함{}'.format(year)]["전입시도"] == select2)]
# a=select_in_내부포함2019.groupby(["전입시군구"]).size()
# b=select_out_내부포함2019.groupby(["전출시군구"]).size()
# a-b

# %%
Select_City="대구광역시"
year= 2019
make_df2(year)
지역in = globals()['select_in{}'.format(year)]["전출시도"]=="경상북도"
사유in= globals()['select_in{}'.format(year)]["사유"]=="주택"
globals()['주택{}in'.format(year)] =globals()['select_in{}'.format(year)][지역in & 사유in]
지역out = globals()['select_out{}'.format(year)]["전입시도"]=="경상북도"
사유out= globals()['select_out{}'.format(year)]["사유"]=="주택"
주택2020out =globals()['select_out{}'.format(year)][지역out & 사유out]

# %%
go_to_city_all(Select_City,"서울특별시")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1188/3116622198.py in <module>
# ----> 1 aa나이_순이동
#
# NameError: name 'aa나이_순이동' is not defined

# %%
select= "대구광역시"
전출도시 ="서울특별시"
for year in years:
    #변수 만들기    
        go_to_city_year(select,전출도시,year)
        go_to_city_year(전출도시,select,year)

    #순이동
        a = globals()[f'{전출도시}_to_{select}']
        b = globals()[f'{select}_to_{전출도시}']
    

        # aabb순이동 = a.groupby(a["전입시도"]).size() - b.groupby(b["전출시도"]).size()
        # globals()['도시비교_순이동']= pd.concat([globals()['도시비교_순이동'], aabb순이동],axis=1)

        # aa_순이동 = a.groupby(a["전입시군구"]).size() - b.groupby(b["전출시군구"]).size()
        # bb_순이동 = b.groupby(b["전입시군구"]).size() - a.groupby(a["전출시군구"]).size()
        # globals()['all_sido_move_1']= pd.concat([globals()['all_sido_move_1'], aa_순이동],axis=1)
        # globals()['all_sido_move_2']= pd.concat([globals()['all_sido_move_2'], bb_순이동],axis=1)
        con_1 =a[a["전입자_만나이"] == "15~19세"]
        con_2 =a[a["전입자_만나이"] == "20~24세"]
        con_3 =a[a["전입자_만나이"] == "25~29세"]
        con_4 =a[a["전입자_만나이"] == "30~34세"]
        con_5 =a[a["전입자_만나이"] == "35~39세"]

        aa_이유순이동 = a.groupby(a["사유"]).size() - b.groupby(b["사유"]).size()
        globals()['all_reason_move']= pd.concat([globals()['all_reason_move'], aa_이유순이동],axis=1)

        aa나이_순이동 = a.groupby(a["전입자_만나이"]).size() - b.groupby(b["전입자_만나이"]).size()
        globals()['all_age_move']= pd.concat([globals()['all_age_move'], aa나이_순이동],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3124/1059276913.py in <module>
#       1 select= "대구광역시"
#       2 전출도시 ="서울특별시"
# ----> 3 for year in years:
#       4     #변수 만들기
#       5         go_to_city_year(select,전출도시,year)
#
# NameError: name 'years' is not defined

# %%
make_df2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7136/1066158991.py in <module>
# ----> 1 make_df2()
#
# ~\AppData\Local\Temp/ipykernel_7136/4095891751.py in make_df2()
#      19
#      20     for year in years:
# ---> 21         make_df1(year)
#      22         #대구시 전입(대구in)- 대구시전출데이터의 전출(대구out)== 순이동
#      23         abcd =globals()['select_in{}'.format(year)].groupby(["전입시도"]).size()
#
# ~\AppData\Local\Temp/ipykernel_7136/3108358850.py in make_df1(year)
#      17                 sheet_name= '행정구역코드 등록 및 말소 내역', skiprows=3)
#      18     abcd= juso_code.iloc[:,1].unique()
# ---> 19     if select_year != "전체기간":
#      20         if os.path.isfile(file):
#      21             print(f"{year}년도 {Select_City}_csv는 이전에 생성되었습니다.'")
#
# NameError: name 'select_year' is not defined
